# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
csv_dataframe  = pd.read_csv('/Users/weichien/Desktop/Moviedata2016.csv', sep=',')

# %%
csv_dataframe
# Out:
#                                        Name  imdb_rating  critics_score  \
# 0                             Suicide Squad          6.2             25
# 1                             Hacksaw Ridge          8.2             87
# 2                                La La Land          8.2             93
# 3   Fantastic Beasts and Where to Find Them          7.4             73
# 4                            Hidden Figures          7.8             93
# 5                                 Moonlight          7.5             98
# 6                                  Deadpool          8.0             84
# 7                              Jack Reacher          6.1             37
# 8               Keeping Up with the Joneses          5.8             19
# 9                              Ghostbusters          5.3             43
# 10                                 Colossal          6.3             79
#
#     audience_score   critics_rating audience_rating best_actor_win  \
# ...
